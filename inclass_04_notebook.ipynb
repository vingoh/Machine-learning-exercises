# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(palette='deep', style='whitegrid')

from sklearn.datasets import load_boston
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# Install __[ipywidgets](https://github.com/jupyter-widgets/ipywidgets/blob/master/README.md#install)__ .
#
# Make sure you run
#
#     jupyter nbextension enable --py --sys-prefix widgetsnbextension
#
# in your terminal for the interactive plots to work

# %% [markdown]
# # How changing the polynomial degree $M$ corresponds to the bias-variance tradeoff

# %% [markdown]
# ### What to talk about
# * Bias variance tradeoff caused by higher/lower polynomial degrees

# %%
# %matplotlib notebook
plt.figure(figsize=[10, 6])
def plot_fit(degree=1, seed=1):
    plt.cla()
    n_samples = 30

    np.random.seed(seed)
    true_fun = lambda X: np.sin(np.pi * X)
    X = np.sort(np.random.uniform(high=2, size=n_samples))
    y = true_fun(X) + np.random.randn(n_samples) * 0.1
    
    polynomial_features = PolynomialFeatures(degree=degree, include_bias=False)
    linear_regression = LinearRegression()
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X[:, np.newaxis], y)

    X_test = np.linspace(0, 2, 100)
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.scatter(X, y, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 2))
    plt.ylim((-2, 2))
    plt.legend(loc=1)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
interact(plot_fit, degree=(1, 30, 1), seed=(1, 10, 1));
# Out:
# interactive(children=(IntSlider(value=1, description='degree', max=30, min=1), IntSlider(value=1, description=…

# %% [markdown]
# # How changing the regularization strength $\lambda$ corresponds to the bias-variance tradeoff

# %% [markdown]
# ### What to talk about
# * Bias variance tradeoff caused by higher/lower regularization strength

# %%
# %matplotlib notebook
plt.figure(figsize=[10, 6])
def ridge_polynomial(log_lambda=0, seed=1):
    plt.cla()
    n_samples = 20

    true_fun = lambda X: np.sin(np.pi * X)
    np.random.seed(seed)
    X = np.sort(np.random.uniform(high=2, size=n_samples))
    y = true_fun(X) + np.random.randn(n_samples) * 0.1
    

    polynomial_features = PolynomialFeatures(degree=15, include_bias=False)
    linear_regression = Ridge(alpha=np.power(10, log_lambda))
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X[:, np.newaxis], y)

    X_test = np.linspace(0, 2, 100)
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.scatter(X, y, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 2))
    plt.ylim((-2, 2))
    plt.legend(loc=1)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
interact(ridge_polynomial, log_lambda=(-15, 10, 1.0), seed=(1, 10, 1));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='log_lambda', max=10.0, min=-15.0, step=1.0), IntSlid…

# %% [markdown]
# # Shrinkage with $L_2$ (ridge) and $L_1$ (lasso) regularization

# %% [markdown]
# ### What to talk about
# * Other types of regularization are possible, not necessarily $L_2$, any $L_p$ norm for $p \geq 1$ can be used.
# * Using $0 < p < 1$ leads to nonconvex objective.
# * Using $L_0$ pseudonorm is impossible to optimize with tools discussed in this course, this is called *Compressed sensing* -> entire research discipline.
# * $L_2$ is called **Ridge** leads to smaller values of $\mathbf{w}$ overall, but no entries are equal to 0. Also easier to optimize.
# * $L_1$ is called **Lasso**, leads to sparse $\mathbf{w}$ (lots of entries are equal to 0)
# * You can combine both penalties -> Elastic net
# * http://www.ds100.org/sp17/assets/notebooks/linear_regression/norm_balls.png
# * There exist other regularization schemes, doesn't have to be weight penalty. In general, regularization - decreasing model capacity / increasing bias / reducing variance.

# %%
data = load_boston()
X = data['data']
y = data['target']
names = data['feature_names']

# %%
lambdas = np.logspace(-4, 4, num=100)
# Ridge regression
coefs_ridge = []
for a in lambdas:
    ridge = ElasticNet(alpha=a, l1_ratio=0)
    ridge.fit(X, y)
    coefs_ridge.append(ridge.coef_)
coefs_ridge = np.array(coefs_ridge)

# Lasso
coefs_lasso = []
for a in lambdas:
    lasso = ElasticNet(alpha=a, l1_ratio=1)
    lasso.fit(X, y)
    coefs_lasso.append(lasso.coef_)
coefs_lasso = np.array(coefs_lasso)
# Out:
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5547.761568118916, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5549.41284196835, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5551.375866718131, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5553.703573224448, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5556.455437197974, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5559.69728459619, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5563.500611887754, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5567.9412584897855, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5573.097269805997, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5579.045823454881, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5585.8591749099505, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5593.599726010495, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5602.314534631501, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5612.0298495713205, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5622.746524360388, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5634.437357669708, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5647.047427756787, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5660.4982499072685, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5674.6960660712075, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5689.5438506634155, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5704.955861430263, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5720.87300276169, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5737.277082102342, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5754.2022848045035, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5771.7427742322, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5790.056041959496, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5809.362271770915, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5829.940392330751, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5852.121632230055, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5876.2813021024385, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5902.829301883431, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5932.199581252054, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5964.8385452753255, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6001.192258642186, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6041.692323917518, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6086.740560041112, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6136.693137174461, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6191.845611887131, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6252.421197104621, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6318.565278679116, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6390.349240737437, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6467.785736932044, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6550.855578865503, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6639.543776596952, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6733.87973017107, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6833.975040291687, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6940.052521905312, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7052.461828063878, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7171.6800587407715, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7298.298905949361, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7433.002370852707, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7576.54032902074, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7729.703095025386, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7893.300815018665, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8068.149251149156, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8255.060574128898, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8454.834514642713, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8668.242286502058, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8895.994052778164, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9138.681417507212, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9396.69018979504, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9670.085401166441, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9958.479211978012, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10260.901027661304, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10575.695480657421, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10900.475558526323, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11232.153391468306, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11567.059815927221, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11901.14761059996, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12230.25606789509, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12550.401125520588, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12858.049684032516, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13150.340574430493, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13425.226407316342, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13681.526367621615, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13918.895387981722, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14137.72653426614, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14339.009302739161, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14524.167189366648, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14694.894883336088, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14853.01064256689, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15000.334388689933, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15138.597705370734, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15269.388437554522, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15394.129694079085, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15514.090346523566, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15630.421400414634, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15744.210096857563, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15856.541815459695, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15968.559350865879, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16081.510154535597, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16196.774386119101, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16315.869409399784, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16440.42891419721, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16572.156634714363, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16712.755630684103, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16863.834735355347, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17026.794775519418, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17202.699253638533, tolerance: 4.2716295415019765
#   positive)
# /Users/hpj123/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17392.13773950065, tolerance: 4.2716295415019765
#   positive)

# %%
# %matplotlib inline
sns.set(font_scale=2, style='whitegrid')
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=[30, 15])
# Plot ridge
for i in range(13):
    mask = coefs_ridge[:, i] != 0
    ax1.semilogx(lambdas[mask], coefs_ridge[:, i][mask], label=names[i])
ax1.set_xlabel('log $\lambda$ ')
ax1.set_ylabel('Coefficients values')
ax1.set_title('Ridge regression ($L_2$)')
ax1.set_xlim(right=1e4)
ax1.legend()

# Plot lasso
for i in range(13):
    # don't plot the parts where the coefficient is equal to 0
    mask = coefs_lasso[:, i] != 0
    mask[np.where(~mask)[0][0]] = True  
    ax2.semilogx(lambdas[mask], coefs_lasso[:, i][mask], label=names[i])
ax2.set_xlabel('log $\lambda$ ')
ax2.set_title('Lasso ($L_1$)')
ax2.set_xlim(right=1e4)
ax2.legend()
plt.show()

# %% [markdown]
# ### Interpretation of the plots
# The plots show how values of model weights change as regularization scale increases.
#
# In the plots we confirm these facts:
# * $L_2$ leads to smaller values of $\mathbf{w}$ overall, but no entries are equal to 0.
# * $L_1$ leads to sparse $\mathbf{w}$ (lots of entries are equal to 0 as log lambda increases).
# * More on weights regularization in Section 3.4 of https://web.stanford.edu/~hastie/Papers/ESLII.pdf
